# %%
import os
from IPython.display import display, Markdown
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
GEMINI_BASE_URL = 'https://generativelanguage.googleapis.com/v1beta/openai/'
GEMINI_API_KEY = os.getenv('GOOGLE_API_KEY')
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=GEMINI_API_KEY)

# %%
system_prompt = """
You are a helpful education coach to help to design a professional 4 weeks plan for the user based on the job title. 
If the job title is not valid, please say so and ask user to input the correct job title again. 
If the job title is valid, Response in markdown. Do not wrap the markdown with code block - reply only in markdown.
"""
user_prompt = """
You will analyze the job title provided by user, think thoroughly before providing a professional plan regarding the structures of the learning path, provide useful link for the learning & tips to achieve success for the user.
This is the job title user wish to expertise on:

"""

# %%
job = "machine learning engineer"

message = [
    {'role': 'system', 'content': system_prompt},
    {'role': 'user', 'content': user_prompt + job}
]


response = gemini.chat.completions.create(model='gemini-3.1-flash-lite-preview', messages=message)
result = response.choices[0].message.content
display(Markdown(result))
# Out:
# # 4-Week Professional Roadmap: Machine Learning Engineer
#
# Becoming a Machine Learning (ML) Engineer requires a bridge between data science and software engineering. This plan focuses on high-impact areas to get you production-ready.
#
# ## Week 1: Mathematics and Foundation Refresher
# *Focus: Understanding the "Why" behind the algorithms.*
#
# *   **Key Topics:**
#     *   **Linear Algebra:** Matrices, vectors, eigenvalues, and SVD.
#     *   **Calculus:** Partial derivatives, gradients, and the chain rule (essential for Backpropagation).
#     *   **Statistics:** Probability distributions, hypothesis testing, and Bayesian inference.
# *   **Action Items:** Review how Gradient Descent works mathematically.
# *   **Resources:**
#     *   [Khan Academy: Linear Algebra](https://www.khanacademy.org/math/linear-algebra)
#     *   [StatQuest with Josh Starmer (YouTube)](https://www.youtube.com/user/joshstarmer)
#
# ## Week 2: Core ML Algorithms and Scikit-Learn
# *Focus: Moving from theory to practical implementation.*
#
# *   **Key Topics:**
#     *   **Supervised Learning:** Linear/Logistic Regression, Random Forests, Gradient Boosting (XGBoost/LightGBM).
#     *   **Unsupervised Learning:** K-Means, PCA, t-SNE.
#     *   **Evaluation Metrics:** Precision/Recall, F1-Score, ROC-AUC, RMSE.
# *   **Action Items:** Build an end-to-end project on Kaggle using Scikit-Learn to solve a classification problem.
# *   **Resources:**
#     *   [Scikit-Learn Documentation](https://scikit-learn.org/stable/)
#     *   [Kaggle: Learn ML Courses](https://www.kaggle.com/learn)
#
# ## Week 3: Deep Learning and Frameworks
# *Focus: Mastering Neural Networks for complex data (Images/Text).*
#
# *   **Key Topics:**
#     *   **Frameworks:** Choose PyTorch (industry preference) or TensorFlow.
#     *   **Architectures:** CNNs (Computer Vision), RNNs/LSTMs (Sequential data), and an introduction to Transformers.
#     *   **Techniques:** Dropout, Batch Normalization, Adam Optimizer.
# *   **Action Items:** Implement a simple Neural Network from scratch using NumPy, then redo it using PyTorch.
# *   **Resources:**
#     *   [DeepLearning.AI (Coursera)](https://www.coursera.org/specializations/deep-learning)
#     *   [PyTorch Tutorials](https://pytorch.org/tutorials/)
#
# ## Week 4: MLOps and Model Deployment
# *Focus: Bridging the gap between "notebook models" and "production systems."*
#
# *   **Key Topics:**
#     *   **MLOps:** Model versioning (DVC), tracking (MLflow), and experiment management.
#     *   **Deployment:** Containerization (Docker), REST APIs (FastAPI/Flask), and Cloud deployment (AWS/GCP/Azure).
#     *   **Data Pipelines:** Basic ETL processes and feature stores.
# *   **Action Items:** Take a model you built in Week 2/3, containerize it with Docker, and deploy it as a simple API on a cloud provider.
# *   **Resources:**
#     *   [Full Stack Deep Learning](https://fullstackdeeplearning.com/)
#     *   [MLOps.community](https://mlops.community/)
#
# ---
#
# ## Tips for Success
#
# 1.  **Build, Don't Just Watch:** You cannot learn ML by watching videos. Spend 70% of your time coding and 30% studying theory.
# 2.  **Focus on Data Quality:** A great model cannot fix bad data. Learn how to clean, impute, and feature-engineer your datasets effectively.
# 3.  **Learn Version Control:** ML Engineers are Software Engineers first. Master Git, branching, and pull requests.
# 4.  **Read Research Papers:** Once you grasp the basics, try to read one paper a week from [ArXiv](https://arxiv.org/) related to your area of interest (e.g., NLP or Computer Vision).
# 5.  **Community Matters:** Join Discord servers or LinkedIn groups focused on MLOps to stay updated on the fast-moving AI landscape.
