# %%
import os
from IPython.display import display, Markdown
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
GEMINI_BASE_URL = 'https://generativelanguage.googleapis.com/v1beta/openai/'
GEMINI_API_KEY = os.getenv('GOOGLE_API_KEY')
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=GEMINI_API_KEY)

# %%
OLLAMA_BASE_URL = 'http://localhost:11434/v1'
OLLAMA_API_KEY = 'ollama' # can be any words, not important
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key=OLLAMA_API_KEY)

# %%
system_prompt = """
You are a helpful education coach to help to design a professional 4 weeks plan for the user based on the job title. 
If the job title is not valid, please say so and ask user to input the correct job title again. 
If the job title is valid, Response in markdown. Do not wrap the markdown with code block - reply only in markdown.
"""
user_prompt = """
You will analyze the job title provided by user, think thoroughly before providing a professional plan regarding the structures of the learning path, provide useful link for the learning & tips to achieve success for the user.
This is the job title user wish to expertise on:

"""

# %%
job = "machine learning engineer"

message = [
    {'role': 'system', 'content': system_prompt},
    {'role': 'user', 'content': user_prompt + job}
]

# %%
#GEMINI

gemini_response = gemini.chat.completions.create(model='gemini-3.1-flash-lite-preview', messages=message)
result = gemini_response.choices[0].message.content
display(Markdown(result))
# Out:
# # 4-Week Intensive Roadmap: Machine Learning Engineer
#
# To become a proficient Machine Learning Engineer (MLE), you must balance theoretical mathematics, coding proficiency, and MLOps infrastructure. This plan assumes you have a foundational grasp of Python.
#
# ---
#
# ### Week 1: Mathematics & Core Algorithms
# **Goal:** Master the "under-the-hood" mechanics of ML models.
#
# *   **Key Topics:**
#     *   **Linear Algebra & Calculus:** Matrix multiplication, derivatives, and gradient descent.
#     *   **Probability & Statistics:** Bayes’ Theorem, distributions, and hypothesis testing.
#     *   **Classical ML:** Linear/Logistic Regression, Decision Trees, SVMs, and K-Means.
# *   **Resources:**
#     *   [Mathematics for Machine Learning (Book/Course)](https://mml-book.github.io/)
#     *   [StatQuest with Josh Starmer (YouTube)](https://www.youtube.com/c/StatQuestwithJoshStarmer)
# *   **Success Tip:** Don’t just memorize formulas. Implement Linear Regression from scratch using only `NumPy`.
#
# ---
#
# ### Week 2: Deep Learning & Frameworks
# **Goal:** Transition from classical algorithms to Neural Networks.
#
# *   **Key Topics:**
#     *   **Frameworks:** Get comfortable with **PyTorch** or **TensorFlow**.
#     *   **Neural Nets:** Backpropagation, Activation Functions, and Optimizers.
#     *   **Architectures:** CNNs (Computer Vision) and Transformers (NLP).
# *   **Resources:**
#     *   [DeepLearning.AI Specialization (Coursera)](https://www.coursera.org/specializations/deep-learning)
#     *   [PyTorch Tutorials](https://pytorch.org/tutorials/)
# *   **Success Tip:** Start a small project on Kaggle. Use a pre-trained model (Transfer Learning) to solve a classification problem.
#
# ---
#
# ### Week 3: MLOps & Data Engineering
# **Goal:** Move from "Model in a Jupyter Notebook" to "Model in Production."
#
# *   **Key Topics:**
#     *   **Data Pipelines:** SQL, ETL processes, and handling imbalanced datasets.
#     *   **Model Deployment:** FastAPI/Flask to wrap models in APIs.
#     *   **Version Control:** DVC (Data Version Control) and MLflow.
#     *   **Cloud Basics:** Familiarity with AWS SageMaker or Google Vertex AI.
# *   **Resources:**
#     *   [Made With ML (Free, comprehensive MLOps course)](https://madewithml.com/)
#     *   [MLflow Documentation](https://mlflow.org/docs/latest/index.html)
# *   **Success Tip:** Learn to use Docker. If your model can't be containerized, it isn't ready for production.
#
# ---
#
# ### Week 4: Capstone Project & Portfolio
# **Goal:** Build a production-ready end-to-end ML application.
#
# *   **Key Topics:**
#     *   Building a complete system: Data collection $\rightarrow$ Training $\rightarrow$ Evaluation $\rightarrow$ Deployment.
#     *   Writing clean, modular production code (PEP 8 standards).
#     *   Technical documentation (README.md, architecture diagrams).
# *   **Project Ideas:**
#     *   Real-time sentiment analysis API.
#     *   An automated image classifier with a web front-end.
# *   **Resources:**
#     *   [GitHub Documentation on Writing READMEs](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax)
# *   **Success Tip:** Quality over quantity. A single, well-documented project with a live demo or clear GitHub repo is worth more than ten "Titanic Dataset" tutorials.
#
# ---
#
# ### Pro Tips for Success
#
# 1.  **Prioritize SQL:** MLEs spend 80% of their time cleaning and querying data. If you can't join tables efficiently, your modeling will stall.
# 2.  **Learn Version Control (Git):** In a professional setting, collaboration is non-negotiable. Master branching, merging, and pull requests.
# 3.  **Focus on Metrics, Not Just Accuracy:** Understand when to use Precision, Recall, F1-Score, or AUC-ROC. Business stakeholders care about costs and errors, not just raw accuracy.
# 4.  **Network on LinkedIn:** Follow industry leaders and contributors to open-source ML libraries. Contribute to small issues on GitHub to build your profile.
# 5.  **Stay Updated:** Read research papers from [arXiv](https://arxiv.org/list/cs.LG/recent) occasionally to see where the industry is heading.

# %%
#OLLAMA

ollama_response = ollama.chat.completions.create(model='gpt-oss:latest', messages=message)
result = ollama_response.choices[0].message.content
display(Markdown(result))
# Out:
# ## 4‑Week Roadmap to Become a Machine‑Learning Engineer
#
# > **TL;DR** – A focused, actionable learning track that blends theory, coding, and real‑world practice.
# > Each week starts with a goal, followed by the *why*, *what to study*, *practical tasks*, and *handy links*.
#
# ---
#
# ### Week 1 – Foundations & Tooling
# **Goal:** Build a solid mathematical and programming base, set up your environment, and understand the ML pipeline at a high level.
#
# | # | Focus | Why it matters | What to do | Resources |
# |---|-------|----------------|------------|-----------|
# | 1 | *Linear Algebra* | Matrix ops are the “DNA” of ML. | Take the first 3‑6 modules of **[MIT 18.06 Linear Algebra](https://ocw.mit.edu/courses/mathematics/18-06-linear-algebra-spring-2010/)** (video + notes). | |
# | 2 | *Calculus & Probability* | Gradient descent & randomness drive learning algorithms. | Complete **[Probability for CS & ML](https://www.coursera.org/specializations/probability> )** + a 2‑hour Khan Academy refresher on **partial derivatives**. | |
# | 3 | *Python for ML* | Coding skills enable you to implement theory. | Work through **[Python for Everybody](https://www.coursera.org/specializations/python> )**; finish all exercises & the final project. | |
# | 4 | *Jupyter, Git & Virtual Environments* | Reproducibility & collaboration are non‑negotiable. | Set up a **conda** VM, install **JupyterLab**, Git, and create a first repo on GitHub. Push a “Hello‑World” notebook. | |
# | 5 | *ML Pipeline Overview* | Knowing the stages helps in future troubleshooting. | Read the **[Stanford CS229 Slides – Chapter 1](https://see.stanford.edu/materials/see_cs229/ch01.html)** and draft your own pipeline diagram. | |
#
# > **Key Deliverable:** A GitHub repo hosting a 2‑page Jupyter notebook that walks through basic linear algebra (matrix multiplication, eigenvalues) and one basic probability exercise (expected value).
#
# ---
#
# ### Week 2 – Classic ML Algorithms
# **Goal:** Master supervised & unsupervised learning fundamentals and implement them from scratch.
#
# | # | Focus | Key Concepts | What to do | Resources |
# |---|-------|--------------|------------|-----------|
# | 1 | *Regression & Gradient Descent* | Predict numeric outputs with error minimization. | Re‑implement **linear regression** in NumPy (no scikit‑learn), visualize loss surface. | **[3Blue1Brown – “Linear Algebra for Machine Learning”](https://www.youtube.com/playlist?list=PLZHQObOWTQDMsr9K-rjNKKMZbL4q4k1vR)** |
# | 2 | *Classification* | Map inputs to discrete labels. | Code **logistic regression**, **k‑NN**, **SVM** from scratch; compare results on **Iris** dataset. | **[Machine Learning Crash Course – Classification](https://developers.google.com/machine-learning/crash-course)** |
# | 3 | *Decision Trees & Ensemble Methods* | Interpretability + non‑linear modeling. | Build a **decision tree** (ID3) and a **random forest**; experiment with depth & bootstrapping. | **[StatQuest – Random Forests](https://www.youtube.com/watch?v=JtPqj_4J-2Y)** |
# | 4 | *Clustering* | Grouping patterns without labels. | Implement **k‑means** and **DBSCAN**; cluster the **MNIST** digits (use 784‑dim vectors). | **[Hands‑on Machine Learning with scikit‑learn, Keras & MLflow](https://www.oreilly.com/library/view/hands-on-machine-learning/9781789955750/)** (Chapter 8) |
# | 5 | *Model Evaluation* | Measure bias‑variance trade‑off, avoid overfitting. | Practice **cross‑validation**, **ROC‑AUC**, confusion matrix. | **[Andrew Ng – ML on Coursera](https://www.coursera.org/learn/machine-learning)** (Week 7) |
#
# > **Key Deliverable:** A single notebook that runs a full pipeline: data loading → training → evaluation → interpretation for at least two different algorithms.
#
# ---
#
# ### Week 3 – Deep Learning & Modern Frameworks
# **Goal:** Grasp neural networks, architecture design, and best practices in TensorFlow or PyTorch.
#
# | # | Focus | Why | What to do | Resources |
# |---|-------|-----|------------|-----------|
# | 1 | *Neural Network Basics* | Understanding backpropagation & activation patterns. | Code a **two‑layer perceptron** in NumPy; visualize gradients. | **[CS231n Blog – Backprop](https://cs231n.github.io/backprop/)** |
# | 2 | *CNNs for Images* | Convolution layers capture spatial hierarchies. | Train a small CNN on **FashionMNIST** using **PyTorch Lightning**; tweak kernel size, strides. | **[Deep Learning for Computer Vision by Stanford (CS231n)](https://cs231n.github.io/)** |
# | 3 | *RNNs / Transformers* | Sequence data requires temporal modeling. | Implement a simple **LSTM** to predict next character of a Shakespeare quote; later prototype a **Transformer encoder** on a toy text task. | **[Fast.ai – NLP Course (Practical Deep Learning for Coders)](https://course.fast.ai/)** |
# | 4 | *Model Training & Deployment* | Scaling, reproducibility, and serving. | Experiment with **Weights & Biases**, set up **Docker** to containerize your model, and host it on Kaggle Kernels. | **[TensorFlow Serving](https://www.tensorflow.org/tfx/serving)** |
# | 5 | *Fine‑Tuning & Transfer Learning* | Leverage pre‑trained models to get quick results. | Fine‑tune **ResNet‑50** on your own image set (e.g., pet breeds). | **[Transfer Learning in PyTorch](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html)** |
#
# > **Key Deliverable:** A small project (e.g., image classifier or text generator) deployed as a single executable script (or Docker image) with a clean README.
#
# ---
#
# ### Week 4 – Portfolio, Community, and Career Prep
# **Goal:** Showcase your skills, engage with the ML community, and prepare to land a role.
#
# | # | Focus | Why | What to do | Resources |
# |---|-------|-----|------------|-----------|
# | 1 | *Kaggle Competitions* | Real‑world problem solving + bragging rights. | Pick an **“Getting Started”** Kaggle challenge (e.g., Titanic or House Prices). Aim for at least a 70 % leaderboard rank. | **[Kaggle Learn Micro‑Courses](https://www.kaggle.com/learn)** |
# | 2 | *GitHub & ReadMe* | Portfolio = first impression. | Consolidate your notebooks, scripts, and Dockerfiles. Write a concise, jargon‑free README explaining problem, solution, results, and insights. | **[Open Source Guide – README.md](https://opensource.guide/how-to-write-a-good-readme/)** |
# | 3 | *Resume & LinkedIn* | Clear, concise storytelling. | Update your résumé to include metrics (e.g., “Improved accuracy by 3 % on X dataset”); set up a professional LinkedIn profile with project links. | **[RESUME.io](https://resume.io/)** |
# | 4 | *Mock Interviews & Soft Skills* | Hiring panels look beyond code. | Practice coding interviews on **LeetCode** (ML‑specific questions) and behavioral rounds (STAR method). Engage in ML podcasts/threads on **Reddit r/MachineLearning**, **DataTau**. | **[InterviewBit – ML interviews](https://www.interviewbit.com/data-science-interview-questions/)** |
# | 5 | *Continual Learning Plan* | ML field evolves fast. | Draft a 6‑month roadmap: focus on a niche (e.g., NLP), attend 1 conference webinar per month, and subscribe to **ML‑weekly** newsletters. | **[Towards Data Science Newsletter](https://towardsdatascience.com/)**, **[ArXiv Sanity Preserver](https://arxiv-sanity.com/)** |
#
# > **Key Deliverable:** A polished GitHub portfolio page, a live LinkedIn headline (“Machine‑Learning Engineer | Data‑driven model developer”), and at least one completed Kaggle competition.
#
# ---
#
# ## Quick Reference: Essential Libraries & Tools
#
# | Category | Tool | Link |
# |----------|------|------|
# | Programming | Python | <https://python.org> |
# | Notebook | JupyterLab | <https://jupyter.org> |
# | ML Framework | PyTorch | <https://pytorch.org> |
# | ML Framework | TensorFlow | <https://www.tensorflow.org> |
# | Version Control | Git + GitHub | <https://github.com> |
# | Experiment Tracking | Weights & Biases | <https://wandb.ai> |
# | CI/CD | Docker | <https://www.docker.com> |
# | Cloud | Google Colab / Kaggle Kernels | <https://colab.research.google.com> |
#
# ---
#
# ## Success Tips & Habits
#
# 1. **Apply “learn‑by‑doing.”** Code each concept before you read the next lesson.
# 2. **Use spaced repetition** for formulas—apps like Anki are excellent for remembering derivations.
# 3. **Peer‑review your code**. Pair‑programming or sharing on GitHub pulls helps surface bugs and improves style.
# 4. **Track your progress** in a learning journal: what worked, what didn’t, and next steps.
# 5. **Build a “starter kit”** of reusable functions (data loaders, metric calculators) to speed up later projects.
# 6. **Connect with the community** early: Slack channels, Discord bots, or local meetups can provide motivation and job leads.
# 7. **Set measurable weekly goals**—e.g., “complete 10 Kaggle kernels” or “train a model in ≤ 16 hours.”
# 8. **Stay curious**: follow recent papers on **arXiv** (e.g., *Attention Is All You Need*, *EfficientNet*).
#
# ---
#
# ### Next Step
#
# - **Validate**: If you’re ready, clone the starter GitHub repo, install the environment, and jump to Week 1’s first module.
# - **Questions?** Ask if you’d like deeper dives into any sub‑skill (e.g., reinforcement learning, Bayesian methods, or MLOps pipelines).
