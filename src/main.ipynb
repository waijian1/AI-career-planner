# %%
import os
from IPython.display import display, Markdown
from openai import OpenAI
from playwright.sync_api import sync_playwright
from bs4 import BeautifulSoup
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
GEMINI_BASE_URL = 'https://generativelanguage.googleapis.com/v1beta/openai/'
GEMINI_API_KEY = os.getenv('GOOGLE_API_KEY')
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=GEMINI_API_KEY)

# %%
OLLAMA_BASE_URL = 'http://localhost:11434/v1'
OLLAMA_API_KEY = 'ollama' # can be any words, not important
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key=OLLAMA_API_KEY)

# %%
system_prompt = """
You are a helpful education coach to help to design a professional 4 weeks plan for the user based on the job title. 
If the job title is not valid, please say so and ask user to input the correct job title again. 
If the job title is valid, Response in markdown. Do not wrap the markdown with code block - reply only in markdown.
"""
user_prompt = """
You will analyze the job title provided by user, think thoroughly before providing a professional plan regarding the structures of the learning path, provide useful link for the learning & tips to achieve success for the user.
This is the job title user wish to expertise on:

"""

# %%
job = "machine learning engineer"

message = [
    {'role': 'system', 'content': system_prompt},
    {'role': 'user', 'content': user_prompt + job}
]

# %%
#GEMINI

gemini_response = gemini.chat.completions.create(model='gemini-3.1-flash-lite-preview', messages=message)
result = gemini_response.choices[0].message.content
display(Markdown(result))

# %%
#OLLAMA

ollama_response = ollama.chat.completions.create(model='gpt-oss:latest', messages=message)
result = ollama_response.choices[0].message.content
display(Markdown(result))

# %%
job = 'teacher chemistry'
country = 'malaysia'
jobstring = '+'.join([*job.split(), country])

test_url = "https://www.indeed.com/jobs?q=" + jobstring.lower()

print(test_url)
# Out:
# https://www.indeed.com/jobs?q=teacher+chemistry+malaysia

# %%
import subprocess

job = 'AI engineer'
country = 'Singapore'
querystring = '+'.join([*job.split(), country])

test_url = "https://www.indeed.com/jobs?q=" + querystring.lower()
result = subprocess.run(
    [r"c:\projects\AI-career-planner\.venv\Scripts\python.exe", "webscraping.py", test_url],
    capture_output=True,
    encoding="utf-8",
    cwd="."
)

print(result.stdout)

if result.returncode != 0:
    print("Error:", result.stderr)
# Out:
# Blocked - Indeed.com Access Denied Your request has been blocked. Return home Find jobs Company Reviews Find salaries Sign in Upload your resume Sign in Employers / Post Job Find jobs Company Reviews Find salaries Request Blocked You have been blocked. If you believe this in error, please go to support.indeed.com and reference the following information:
#
# Your Ray ID for this request is 9dc47ce82d32d899
#
# Your current IP for this request is 39.109.214.90 Return home → Troubleshooting Cloudflare Errors Need more help? Contact us

# %%
display(Markdown(result.stdout))
# Out:
# Blocked - Indeed.com Access Denied Your request has been blocked. Return home Find jobs Company Reviews Find salaries Sign in Upload your resume Sign in Employers / Post Job Find jobs Company Reviews Find salaries Request Blocked You have been blocked. If you believe this in error, please go to support.indeed.com and reference the following information:
#
# Your Ray ID for this request is 9dc47ce82d32d899
#
# Your current IP for this request is 39.109.214.90 Return home → Troubleshooting Cloudflare Errors Need more help? Contact us

# %%
import requests

url = "https://jsearch.p.rapidapi.com/search"

params = {
  "query": "machine learning engineer singapore",
  "page": "1"
}

response = requests.get(url, params=params)
print(response.json())
# Out:
# {'message': 'Invalid API key. Go to https://docs.rapidapi.com/docs/keys for more info.'}
